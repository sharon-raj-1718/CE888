# %% [markdown]
# <a href="https://colab.research.google.com/github/sharon-raj-1718/CE888/blob/main/my_recommender_lab_4.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
jester = pd.read_csv('https://raw.githubusercontent.com/albanda/CE888/master/lab4-recommender/jester-data-1.csv', header=None)
jester.head()
# Out:
#    0      1      2      3      4    ...    96     97     98     99     100
# 0   74  -7.82   8.79  -9.66  -8.16  ...  99.00  -5.63  99.00  99.00  99.00
# 1  100   4.08  -0.29   6.36   4.37  ...  -2.14   3.06   0.34  -4.32   1.07
# 2   49  99.00  99.00  99.00  99.00  ...  99.00  99.00  99.00  99.00  99.00
# 3   48  99.00   8.35  99.00  99.00  ...  99.00  99.00  99.00  99.00  99.00
# 4   91   8.50   4.61  -4.17  -5.39  ...   1.55   3.11   6.55   1.80   1.60
#
# [5 rows x 101 columns]

# %%
jester_nan = jester.replace(99, np.nan)

# %%
jester_nan.isna().sum()
# Out:
# 0         81
# 1       8531
# 2       6799
# 3       8341
# 4       9375
#        ...
# 96     14613
# 97     14463
# 98     14317
# 99     14073
# 100    15040
# Length: 101, dtype: int64

# %%
len(jester[0].unique())
# Out:
# 65

# %%
jester_nan.drop(columns=0, axis=1, inplace=True)

# %%
jester_nan.head()
# Out:
#     1     2     3     4     5     6    ...   95    96    97    98    99    100
# 0 -7.82  8.79 -9.66 -8.16 -7.52 -8.50  ...   NaN   NaN -5.63   NaN   NaN   NaN
# 1  4.08 -0.29  6.36  4.37 -2.38 -9.66  ... -0.19 -2.14  3.06  0.34 -4.32  1.07
# 2   NaN   NaN   NaN   NaN  9.03  9.27  ...   NaN   NaN   NaN   NaN   NaN   NaN
# 3   NaN  8.35   NaN   NaN  1.80  8.16  ...   NaN   NaN   NaN   NaN   NaN   NaN
# 4  8.50  4.61 -4.17 -5.39  1.36  1.60  ...  5.73  1.55  3.11  6.55  1.80  1.60
#
# [5 rows x 100 columns]

# %%
jester_nan.mean().sort_values(ascending=True)
# Out:
# 58   -3.833880
# 16   -3.104818
# 44   -2.111891
# 57   -1.990664
# 13   -1.762882
#         ...
# 32    3.155988
# 27    3.189821
# 36    3.312500
# 89    3.574720
# 50    3.665085
# Length: 100, dtype: float64

# %%
arr = jester_nan.values

# %%
np.where(arr!= 99)
# Out:
# (array([    0,     0,     0, ..., 24982, 24982, 24982]),
#  array([ 0,  1,  2, ..., 97, 98, 99]))

# %%
def helper_function(orig, percentage=0.1):
  """
  Replaces 'percentage'% of the original values in 'orig' with 99's
  :param orig: original data array
  :param percentage: percentage of values to replace (0<percentage<1)
  """
  new_data = orig.copy()
  rated = np.where(~np.isnan(orig))
  n_rated = len(rated[0])
  idx = np.random.choice(n_rated, size=int(percentage*n_rated), replace=False)
  new_data[rated[0][idx], rated[1][idx]] = 99
  return new_data, (rated[0][idx], rated[1][idx])

# %%
new_arr, idx = helper_function(arr)

# %%
arr[idx[0][0], idx[1][0]]
# Out:
# 8.25

# %%
new_arr[idx[0][0], idx[1][0]]
# Out:
# 99.0

# %%
jester.groupby(0).count()
# Out:
#       1     2     3     4     5     6    ...   95    96    97    98    99    100
# 0                                        ...
# 36    482   482   482   482   482   482  ...   482   482   482   482   482   482
# 37    409   409   409   409   409   409  ...   409   409   409   409   409   409
# 38    413   413   413   413   413   413  ...   413   413   413   413   413   413
# 39    391   391   391   391   391   391  ...   391   391   391   391   391   391
# 40    407   407   407   407   407   407  ...   407   407   407   407   407   407
# ..    ...   ...   ...   ...   ...   ...  ...   ...   ...   ...   ...   ...   ...
# 96     68    68    68    68    68    68  ...    68    68    68    68    68    68
# 97     60    60    60    60    60    60  ...    60    60    60    60    60    60
# 98     71    71    71    71    71    71  ...    71    71    71    71    71    71
# 99     81    81    81    81    81    81  ...    81    81    81    81    81    81
# 100  7200  7200  7200  7200  7200  7200  ...  7200  7200  7200  7200  7200  7200
#
# [65 rows x 100 columns]

# %%
def predict_rating(user_id, item_id):
    """ Predict a rating given a user_id and an item_id.
    """
    user_preference = latent_user_preferences[user_id]
    item_preference = latent_item_features[item_id]
    return user_preference.dot(item_preference)


def train(user_id, item_id, rating, alpha=0.0001):
    #print(item_id)
    predicted_rating = predict_rating(user_id, item_id)
    err =  predicted_rating - rating
    #print(err)
    user_pref_values = latent_user_preferences[user_id]
    latent_user_preferences[user_id] -= alpha * err * latent_item_features[item_id]
    latent_item_features[item_id] -= alpha * err * user_pref_values
    return err
    

def sgd(iterations):
    """ Iterate over all users and all items and train for 
        a certain number of iterations
    """
    mse_history = []
    for iteration in range(iterations):
        error = []
        for user_id in range(latent_user_preferences.shape[0]):
            for item_id in range(latent_item_features.shape[0]):
                rating = user_ratings[user_id, item_id]
                if not np.isnan(rating):
                    err = train(user_id, item_id, rating)
                    error.append(err)
        mse = (np.array(error) ** 2).mean()   
        if (iteration % 5) == 0:
            print('Iteration %d/%d:\tMSE=%.6f' % (iteration, iterations, mse))
            mse_history.append(mse)
    return mse_history

# %%
n_latent_factors = 4

user_ratings = jester_nan.values
# Initialise as random values
latent_user_preferences = np.random.random((user_ratings.shape[0], n_latent_factors))
latent_item_features = np.random.random((user_ratings.shape[1], n_latent_factors))

# %%
err  =[]
for u, i in zip(*idx):
  err.append(predict_rating(u,i) - user_ratings[u,i])
print('MSE of validation set: ', (np.array(err)**2).mean())
# Out:
# MSE of validation set:  27.72744203389057

# %%
test_idx = np.where(np.isnan(user_ratings))
for u, i in zip(*test_idx):
  print('Prediction for {} user_id for item_id {} is {}'.format(u, i, predict_rating(u,i)))
# Out:
# Streaming output truncated to the last 5000 lines.
# Prediction for 24812 user_id for item_id 92 is 0.8204113316988149
# Prediction for 24812 user_id for item_id 93 is 0.759736526384662
# Prediction for 24812 user_id for item_id 94 is 0.8538561069432
# Prediction for 24812 user_id for item_id 95 is 0.7902443657599827
# Prediction for 24813 user_id for item_id 70 is 0.5904902470631763
# Prediction for 24813 user_id for item_id 71 is 0.6132012689111576
# Prediction for 24813 user_id for item_id 72 is 0.060191806098596756
# Prediction for 24813 user_id for item_id 73 is 0.34220182275990296
# Prediction for 24813 user_id for item_id 74 is 0.3418798381217139
# Prediction for 24813 user_id for item_id 75 is 0.3940933155256054
# Prediction for 24813 user_id for item_id 76 is 0.9101848061519932
# Prediction for 24813 user_id for item_id 77 is 0.6761565055402762
# Prediction for 24813 user_id for item_id 78 is 0.598941053014152
# Prediction for 24813 user_id for item_id 79 is 0.6133085133418869
# Prediction for 24813 user_id for item_id 80 is 0.7041236650429299
# Prediction for 24813 user_id for item_id 81 is 0.22152790379521814
# Prediction for 24813 user_id for item_id 83 is 0.4804367770633964
# Prediction for 24813 user_id for item_id 85 is 0.4264337201393159
# Prediction for 24813 user_id for item_id 86 is 0.34703814514739073
# Prediction for 24813 user_id for item_id 87 is 0.2590256593222595
# Prediction for 24813 user_id for item_id 88 is 0.3962012461822727
# Prediction for 24813 user_id for item_id 89 is 0.25901893035450324
# Prediction for 24813 user_id for item_id 90 is 0.44445205958548156
# Prediction for 24813 user_id for item_id 91 is 0.6211927186756274
# Prediction for 24813 user_id for item_id 92 is 0.5552254414985291
# Prediction for 24813 user_id for item_id 93 is 0.7375365258435573
# Prediction for 24813 user_id for item_id 95 is 0.5210964136824537
# Prediction for 24813 user_id for item_id 96 is 0.3263016440650453
# Prediction for 24813 user_id for item_id 97 is 0.6311619676532273
# Prediction for 24813 user_id for item_id 98 is 0.652109762015331
# Prediction for 24813 user_id for item_id 99 is 0.6274324072635135
# Prediction for 24814 user_id for item_id 0 is 1.4698733055187456
# Prediction for 24814 user_id for item_id 1 is 1.3691813616252857
# Prediction for 24814 user_id for item_id 2 is 1.118101125283827
# Prediction for 24814 user_id for item_id 3 is 1.1974367539074122
# Prediction for 24814 user_id for item_id 5 is 1.0109848519703475
# Prediction for 24814 user_id for item_id 8 is 2.4519939058783304
# Prediction for 24814 user_id for item_id 9 is 1.6370180219689323
# Prediction for 24814 user_id for item_id 10 is 1.8948068129984592
# Prediction for 24814 user_id for item_id 11 is 1.090181174116479
# Prediction for 24814 user_id for item_id 13 is 2.4637176734184045
# Prediction for 24814 user_id for item_id 21 is 2.2555001552530145
# Prediction for 24814 user_id for item_id 22 is 1.7986924770892765
# Prediction for 24814 user_id for item_id 23 is 2.173918834724753
# Prediction for 24814 user_id for item_id 24 is 2.350683088333461
# Prediction for 24814 user_id for item_id 25 is 2.5061311141207154
# Prediction for 24814 user_id for item_id 28 is 2.0199361926206616
# Prediction for 24814 user_id for item_id 29 is 1.9322256443626604
# Prediction for 24814 user_id for item_id 32 is 1.3381643488366257
# Prediction for 24814 user_id for item_id 36 is 1.1263007065721211
# Prediction for 24814 user_id for item_id 37 is 1.4084909636534844
# Prediction for 24814 user_id for item_id 38 is 1.5199952978696851
# Prediction for 24814 user_id for item_id 40 is 1.386319220376853
# Prediction for 24814 user_id for item_id 42 is 1.635124943225199
# Prediction for 24814 user_id for item_id 43 is 1.8588517362964116
# Prediction for 24814 user_id for item_id 44 is 1.2739340262438141
# Prediction for 24814 user_id for item_id 50 is 1.4660777602193429
# Prediction for 24814 user_id for item_id 51 is 1.9666188080934777
# Prediction for 24814 user_id for item_id 53 is 2.381053402667888
# Prediction for 24814 user_id for item_id 54 is 0.8087454385514644
# Prediction for 24814 user_id for item_id 56 is 1.5746195995720222
# Prediction for 24814 user_id for item_id 57 is 1.1787433958460891
# Prediction for 24814 user_id for item_id 58 is 1.0674937834140645
# Prediction for 24814 user_id for item_id 59 is 0.4267661413502547
# Prediction for 24814 user_id for item_id 62 is 1.3131857891426757
# Prediction for 24814 user_id for item_id 63 is 2.0861093938943167
# Prediction for 24814 user_id for item_id 66 is 1.6780148568962003
# Prediction for 24814 user_id for item_id 71 is 1.4478405498899134
# Prediction for 24814 user_id for item_id 72 is 0.47573254444376367
# Prediction for 24814 user_id for item_id 73 is 1.1226237983356222
# Prediction for 24814 user_id for item_id 74 is 0.8407976585314288
# Prediction for 24814 user_id for item_id 75 is 0.8321728723579422
# Prediction for 24814 user_id for item_id 76 is 1.9279318996507457
# Prediction for 24814 user_id for item_id 77 is 1.5054459160899976
# Prediction for 24814 user_id for item_id 78 is 1.6125498476960136
# Prediction for 24814 user_id for item_id 79 is 1.9430439684163976
# Prediction for 24814 user_id for item_id 80 is 1.577475909645437
# Prediction for 24814 user_id for item_id 81 is 1.15007565027293
# Prediction for 24814 user_id for item_id 82 is 1.1777922447345626
# Prediction for 24814 user_id for item_id 83 is 1.4176874995309028
# Prediction for 24814 user_id for item_id 84 is 1.3620214917339573
# Prediction for 24814 user_id for item_id 85 is 1.3132445034944347
# Prediction for 24814 user_id for item_id 87 is 0.6454452280146546
# Prediction for 24814 user_id for item_id 88 is 1.007770781110269
# Prediction for 24814 user_id for item_id 89 is 1.202053868312622
# Prediction for 24814 user_id for item_id 90 is 1.3625096769809986
# Prediction for 24814 user_id for item_id 91 is 1.6820595072898101
# Prediction for 24814 user_id for item_id 92 is 1.600823366476875
# Prediction for 24814 user_id for item_id 93 is 1.9334922609811762
# Prediction for 24814 user_id for item_id 95 is 1.7492868696634618
# Prediction for 24814 user_id for item_id 96 is 1.1006694426878059
# Prediction for 24814 user_id for item_id 97 is 1.8468198644332878
# Prediction for 24814 user_id for item_id 98 is 1.7806796000876113
# Prediction for 24814 user_id for item_id 99 is 1.8003917513071308
# Prediction for 24815 user_id for item_id 70 is 0.510822552242376
# Prediction for 24815 user_id for item_id 71 is 0.4356895446669084
# Prediction for 24815 user_id for item_id 72 is 0.11100619376465494
# Prediction for 24815 user_id for item_id 73 is 0.3452096144689524
# Prediction for 24815 user_id for item_id 74 is 0.2454447241318093
# Prediction for 24815 user_id for item_id 75 is 0.2691578233111424
# Prediction for 24815 user_id for item_id 76 is 0.6580856039779173
# Prediction for 24815 user_id for item_id 77 is 0.5338199730585607
# Prediction for 24815 user_id for item_id 78 is 0.5320142495152016
# Prediction for 24815 user_id for item_id 79 is 0.5751979726394757
# Prediction for 24815 user_id for item_id 80 is 0.5364339219931714
# Prediction for 24815 user_id for item_id 81 is 0.27325271427145414
# Prediction for 24815 user_id for item_id 82 is 0.3755057471153404
# Prediction for 24815 user_id for item_id 83 is 0.45152618600986827
# Prediction for 24815 user_id for item_id 84 is 0.4662911463519917
# Prediction for 24815 user_id for item_id 85 is 0.43623930528648025
# Prediction for 24815 user_id for item_id 87 is 0.18793688106448925
# Prediction for 24815 user_id for item_id 88 is 0.3450425689030599
# Prediction for 24815 user_id for item_id 89 is 0.32030068397539585
# Prediction for 24815 user_id for item_id 90 is 0.41069255286798084
# Prediction for 24815 user_id for item_id 91 is 0.596019836624548
# Prediction for 24815 user_id for item_id 92 is 0.5151846115968739
# Prediction for 24815 user_id for item_id 93 is 0.5928382189296518
# Prediction for 24815 user_id for item_id 94 is 0.5849244420600883
# Prediction for 24815 user_id for item_id 95 is 0.5437675191471879
# Prediction for 24815 user_id for item_id 97 is 0.6042105952785658
# Prediction for 24815 user_id for item_id 98 is 0.5393813768265472
# Prediction for 24815 user_id for item_id 99 is 0.6022574158406362
# Prediction for 24816 user_id for item_id 0 is 1.0574922168270056
# Prediction for 24816 user_id for item_id 1 is 0.6305021086262369
# Prediction for 24816 user_id for item_id 2 is 0.6224734469316389
# Prediction for 24816 user_id for item_id 3 is 0.4916119521842708
# Prediction for 24816 user_id for item_id 8 is 1.1023701929067846
# Prediction for 24816 user_id for item_id 9 is 0.8126681860804881
# Prediction for 24816 user_id for item_id 11 is 0.7209263061627127
# Prediction for 24816 user_id for item_id 21 is 1.2887879799359878
# Prediction for 24816 user_id for item_id 22 is 1.0029067247742833
# Prediction for 24816 user_id for item_id 23 is 1.274351989299424
# Prediction for 24816 user_id for item_id 24 is 1.3270201269414577
# Prediction for 24816 user_id for item_id 29 is 0.44936794243631417
# Prediction for 24816 user_id for item_id 32 is 1.137165221232202
# Prediction for 24816 user_id for item_id 33 is 0.3665426494524854
# Prediction for 24816 user_id for item_id 36 is 0.3888426717080991
# Prediction for 24816 user_id for item_id 37 is 1.167476001514416
# Prediction for 24816 user_id for item_id 40 is 0.9782056093109256
# Prediction for 24816 user_id for item_id 42 is 1.2274200142388163
# Prediction for 24816 user_id for item_id 43 is 0.8773960881864116
# Prediction for 24816 user_id for item_id 44 is 0.5660002712948253
# Prediction for 24816 user_id for item_id 45 is 0.5500661051528096
# Prediction for 24816 user_id for item_id 46 is 1.5616613728424942
# Prediction for 24816 user_id for item_id 50 is 1.140223620136443
# Prediction for 24816 user_id for item_id 54 is 0.5523711660427578
# Prediction for 24816 user_id for item_id 57 is 0.3293850840538609
# Prediction for 24816 user_id for item_id 58 is 0.6261059927343932
# Prediction for 24816 user_id for item_id 59 is 0.3105888752094998
# Prediction for 24816 user_id for item_id 62 is 0.8723132440203851
# Prediction for 24816 user_id for item_id 63 is 1.1404568628259617
# Prediction for 24816 user_id for item_id 66 is 0.8685908845402123
# Prediction for 24816 user_id for item_id 69 is 0.4194794220699475
# Prediction for 24816 user_id for item_id 70 is 1.283508857083867
# Prediction for 24816 user_id for item_id 71 is 0.544340581405883
# Prediction for 24816 user_id for item_id 72 is 0.15051155560100024
# Prediction for 24816 user_id for item_id 73 is 0.629470732081574
# Prediction for 24816 user_id for item_id 74 is 0.1854438316562414
# Prediction for 24816 user_id for item_id 75 is 0.48980382770748343
# Prediction for 24816 user_id for item_id 76 is 1.2264889438426336
# Prediction for 24816 user_id for item_id 77 is 1.2018683603778701
# Prediction for 24816 user_id for item_id 78 is 0.9246851234877858
# Prediction for 24816 user_id for item_id 79 is 1.0429321554598834
# Prediction for 24816 user_id for item_id 80 is 1.0429675999327632
# Prediction for 24816 user_id for item_id 81 is 0.5352929470210418
# Prediction for 24816 user_id for item_id 82 is 0.6708065876095023
# Prediction for 24816 user_id for item_id 83 is 0.8298937136714596
# Prediction for 24816 user_id for item_id 84 is 0.8514444263807492
# Prediction for 24816 user_id for item_id 85 is 0.7157757861571583
# Prediction for 24816 user_id for item_id 86 is 0.9601008414686527
# Prediction for 24816 user_id for item_id 87 is 0.15832122349391153
# Prediction for 24816 user_id for item_id 88 is 0.8529844256142984
# Prediction for 24816 user_id for item_id 89 is 0.6417806756189905
# Prediction for 24816 user_id for item_id 90 is 0.919293561828109
# Prediction for 24816 user_id for item_id 91 is 1.3895360656187117
# Prediction for 24816 user_id for item_id 92 is 1.1455096065207357
# Prediction for 24816 user_id for item_id 93 is 0.643333059150676
# Prediction for 24816 user_id for item_id 94 is 1.019886478367791
# Prediction for 24816 user_id for item_id 95 is 1.0144484841866381
# Prediction for 24816 user_id for item_id 97 is 1.4526532296513348
# Prediction for 24816 user_id for item_id 99 is 1.1007469769976586
# Prediction for 24817 user_id for item_id 0 is 0.42813631396413565
# Prediction for 24817 user_id for item_id 2 is 0.6586343912306735
# Prediction for 24817 user_id for item_id 3 is 0.6068696879849915
# Prediction for 24817 user_id for item_id 8 is 1.2545993412782284
# Prediction for 24817 user_id for item_id 23 is 1.1105377021317526
# Prediction for 24817 user_id for item_id 36 is 0.5537231900557015
# Prediction for 24817 user_id for item_id 43 is 0.8651628222265301
# Prediction for 24817 user_id for item_id 56 is 0.793047735067549
# Prediction for 24817 user_id for item_id 57 is 0.8530672815475815
# Prediction for 24817 user_id for item_id 70 is 0.3960381262906903
# Prediction for 24817 user_id for item_id 71 is 0.7074979352781963
# Prediction for 24817 user_id for item_id 73 is 0.6048234440113939
# Prediction for 24817 user_id for item_id 74 is 0.47313499341100107
# Prediction for 24817 user_id for item_id 75 is 0.30036218135242787
# Prediction for 24817 user_id for item_id 76 is 0.6660930007194101
# Prediction for 24817 user_id for item_id 77 is 0.46492905303765303
# Prediction for 24817 user_id for item_id 78 is 0.7556308451223186
# Prediction for 24817 user_id for item_id 79 is 1.0422296104444286
# Prediction for 24817 user_id for item_id 80 is 0.5707863509405962
# Prediction for 24817 user_id for item_id 81 is 0.7855265356253922
# Prediction for 24817 user_id for item_id 82 is 0.5217060021923428
# Prediction for 24817 user_id for item_id 84 is 0.529851305321594
# Prediction for 24817 user_id for item_id 85 is 0.6904270207833693
# Prediction for 24817 user_id for item_id 86 is 0.9522963657554151
# Prediction for 24817 user_id for item_id 87 is 0.3606812485513026
# Prediction for 24817 user_id for item_id 88 is 0.3490158695893831
# Prediction for 24817 user_id for item_id 89 is 0.7645665824047468
# Prediction for 24817 user_id for item_id 90 is 0.6471652242149216
# Prediction for 24817 user_id for item_id 91 is 0.6359718776131378
# Prediction for 24817 user_id for item_id 92 is 0.7045284849120506
# Prediction for 24817 user_id for item_id 93 is 1.0572913434368323
# Prediction for 24817 user_id for item_id 94 is 0.8822952422269584
# Prediction for 24817 user_id for item_id 95 is 0.9423168112312579
# Prediction for 24817 user_id for item_id 96 is 0.49130682895751426
# Prediction for 24817 user_id for item_id 97 is 0.7739680219033279
# Prediction for 24817 user_id for item_id 98 is 0.8297399856434504
# Prediction for 24817 user_id for item_id 99 is 0.8597961093374763
# Prediction for 24818 user_id for item_id 0 is 0.7611105688930822
# Prediction for 24818 user_id for item_id 1 is 0.9061504134790042
# Prediction for 24818 user_id for item_id 2 is 0.6987002529134958
# Prediction for 24818 user_id for item_id 3 is 0.8499433641878298
# Prediction for 24818 user_id for item_id 5 is 0.5994762408728314
# Prediction for 24818 user_id for item_id 8 is 1.3391173844465392
# Prediction for 24818 user_id for item_id 9 is 1.2634543567200802
# Prediction for 24818 user_id for item_id 10 is 1.0323794230428303
# Prediction for 24818 user_id for item_id 11 is 0.6954625358737948
# Prediction for 24818 user_id for item_id 13 is 1.2725457830157425
# Prediction for 24818 user_id for item_id 21 is 1.2777208869511663
# Prediction for 24818 user_id for item_id 22 is 1.0222793458125008
# Prediction for 24818 user_id for item_id 23 is 0.8966169985077134
# Prediction for 24818 user_id for item_id 24 is 1.2803717281639277
# Prediction for 24818 user_id for item_id 25 is 1.251834898700516
# Prediction for 24818 user_id for item_id 28 is 1.0259468968064744
# Prediction for 24818 user_id for item_id 29 is 1.4272179786743118
# Prediction for 24818 user_id for item_id 30 is 0.4799524610647851
# Prediction for 24818 user_id for item_id 32 is 0.41551442907286407
# Prediction for 24818 user_id for item_id 36 is 0.8836660584784833
# Prediction for 24818 user_id for item_id 37 is 0.6398604101637597
# Prediction for 24818 user_id for item_id 38 is 0.8517474200052856
# Prediction for 24818 user_id for item_id 40 is 0.4941997595865496
# Prediction for 24818 user_id for item_id 43 is 0.9578742182572585
# Prediction for 24818 user_id for item_id 44 is 0.7812968076170953
# Prediction for 24818 user_id for item_id 45 is 0.9204368369468078
# Prediction for 24818 user_id for item_id 50 is 0.6101893506565077
# Prediction for 24818 user_id for item_id 51 is 1.4560177064049131
# Prediction for 24818 user_id for item_id 54 is 0.5002703777161805
# Prediction for 24818 user_id for item_id 56 is 0.9883972852311446
# Prediction for 24818 user_id for item_id 58 is 0.6980659839018294
# Prediction for 24818 user_id for item_id 59 is 0.12006117265220466
# Prediction for 24818 user_id for item_id 62 is 0.4640685664531726
# Prediction for 24818 user_id for item_id 63 is 1.036771123089016
# Prediction for 24818 user_id for item_id 66 is 0.9951997712225887
# Prediction for 24818 user_id for item_id 70 is 0.47009496465979356
# Prediction for 24818 user_id for item_id 71 is 1.0982550879804365
# Prediction for 24818 user_id for item_id 72 is 0.2958283052196613
# Prediction for 24818 user_id for item_id 73 is 0.5640028077956754
# Prediction for 24818 user_id for item_id 74 is 0.6718140996747635
# Prediction for 24818 user_id for item_id 75 is 0.5788166054637905
# Prediction for 24818 user_id for item_id 76 is 1.1469453309495818
# Prediction for 24818 user_id for item_id 77 is 0.701518121205837
# Prediction for 24818 user_id for item_id 78 is 0.7999702006041954
# Prediction for 24818 user_id for item_id 79 is 1.1313436011009688
# Prediction for 24818 user_id for item_id 80 is 0.876080003562366
# Prediction for 24818 user_id for item_id 82 is 0.7036031071159983
# Prediction for 24818 user_id for item_id 83 is 0.7073779917810049
# Prediction for 24818 user_id for item_id 84 is 0.7165679181730401
# Prediction for 24818 user_id for item_id 85 is 0.5404774025345028
# Prediction for 24818 user_id for item_id 86 is 0.9034385679832805
# Prediction for 24818 user_id for item_id 87 is 0.5102251837945917
# Prediction for 24818 user_id for item_id 88 is 0.43227194747718395
# Prediction for 24818 user_id for item_id 89 is 0.6830383086685714
# Prediction for 24818 user_id for item_id 90 is 0.7524219969928756
# Prediction for 24818 user_id for item_id 91 is 0.5576302959376789
# Prediction for 24818 user_id for item_id 92 is 0.7624645523030252
# Prediction for 24818 user_id for item_id 93 is 1.2883098384135472
# Prediction for 24818 user_id for item_id 94 is 0.8936444675419082
# Prediction for 24818 user_id for item_id 95 is 0.82408458161783
# Prediction for 24818 user_id for item_id 97 is 0.7949107372761184
# Prediction for 24818 user_id for item_id 98 is 1.1088297268711877
# Prediction for 24818 user_id for item_id 99 is 0.7729675017402632
# Prediction for 24821 user_id for item_id 0 is 1.2320993394743172
# Prediction for 24821 user_id for item_id 2 is 1.0642321919952253
# Prediction for 24821 user_id for item_id 3 is 1.1166001940208279
# Prediction for 24821 user_id for item_id 8 is 1.7463794406722444
# Prediction for 24821 user_id for item_id 23 is 1.352914718576078
# Prediction for 24821 user_id for item_id 29 is 1.6593182051924786
# Prediction for 24821 user_id for item_id 32 is 0.8645851863893153
# Prediction for 24821 user_id for item_id 36 is 1.112578130027901
# Prediction for 24821 user_id for item_id 37 is 1.229604535826088
# Prediction for 24821 user_id for item_id 40 is 0.8333810470171231
# Prediction for 24821 user_id for item_id 42 is 1.2154611007604927
# Prediction for 24821 user_id for item_id 43 is 1.2452837311546245
# Prediction for 24821 user_id for item_id 54 is 0.8295468466109118
# Prediction for 24821 user_id for item_id 56 is 1.449235465590848
# Prediction for 24821 user_id for item_id 57 is 0.9436639670369048
# Prediction for 24821 user_id for item_id 58 is 1.0085175072998374
# Prediction for 24821 user_id for item_id 59 is 0.2161463772058965
# Prediction for 24821 user_id for item_id 63 is 1.455611693770057
# Prediction for 24821 user_id for item_id 66 is 1.384938590871434
# Prediction for 24821 user_id for item_id 69 is 1.3447162853791734
# Prediction for 24821 user_id for item_id 70 is 1.022038443871597
# Prediction for 24821 user_id for item_id 71 is 1.4088791805879441
# Prediction for 24821 user_id for item_id 72 is 0.3810119125914944
# Prediction for 24821 user_id for item_id 73 is 0.8407810502862212
# Prediction for 24821 user_id for item_id 74 is 0.7757276150470195
# Prediction for 24821 user_id for item_id 75 is 0.8508195811392515
# Prediction for 24821 user_id for item_id 76 is 1.739182792798359
# Prediction for 24821 user_id for item_id 77 is 1.2515508392576766
# Prediction for 24821 user_id for item_id 78 is 1.176169635407929
# Prediction for 24821 user_id for item_id 79 is 1.655701732550621
# Prediction for 24821 user_id for item_id 80 is 1.3676246231592313
# Prediction for 24821 user_id for item_id 81 is 1.1478587537953657
# Prediction for 24821 user_id for item_id 82 is 1.0325745731557372
# Prediction for 24821 user_id for item_id 83 is 1.0667817351894637
# Prediction for 24821 user_id for item_id 84 is 1.0866772349759755
# Prediction for 24821 user_id for item_id 85 is 0.7740783221837069
# Prediction for 24821 user_id for item_id 86 is 1.4512738422432954
# Prediction for 24821 user_id for item_id 87 is 0.6000905193585556
# Prediction for 24821 user_id for item_id 88 is 0.8329527550238781
# Prediction for 24821 user_id for item_id 89 is 1.030472030260671
# Prediction for 24821 user_id for item_id 90 is 1.2364011778338826
# Prediction for 24821 user_id for item_id 91 is 1.120184732341694
# Prediction for 24821 user_id for item_id 92 is 1.303250061813269
# Prediction for 24821 user_id for item_id 93 is 1.563121096709257
# Prediction for 24821 user_id for item_id 94 is 1.3125657610736239
# Prediction for 24821 user_id for item_id 95 is 1.2538485227964788
# Prediction for 24821 user_id for item_id 96 is 0.8454668459867677
# Prediction for 24821 user_id for item_id 97 is 1.474085319011513
# Prediction for 24821 user_id for item_id 98 is 1.6779643875123413
# Prediction for 24821 user_id for item_id 99 is 1.1898104073203906
# Prediction for 24822 user_id for item_id 0 is 0.9900812428398037
# Prediction for 24822 user_id for item_id 1 is 1.0493868409555303
# Prediction for 24822 user_id for item_id 2 is 0.825756962499763
# Prediction for 24822 user_id for item_id 3 is 0.9394783376220921
# Prediction for 24822 user_id for item_id 5 is 0.7498909993249532
# Prediction for 24822 user_id for item_id 8 is 1.8326032482279053
# Prediction for 24822 user_id for item_id 9 is 1.268192790738044
# Prediction for 24822 user_id for item_id 10 is 1.3754544564248667
# Prediction for 24822 user_id for item_id 11 is 0.7771350825601681
# Prediction for 24822 user_id for item_id 13 is 1.7705282056236782
# Prediction for 24822 user_id for item_id 21 is 1.6256195975118521
# Prediction for 24822 user_id for item_id 23 is 1.5057992363597419
# Prediction for 24822 user_id for item_id 24 is 1.6865451534580402
# Prediction for 24822 user_id for item_id 29 is 1.6121793816981533
# Prediction for 24822 user_id for item_id 32 is 0.815475751083511
# Prediction for 24822 user_id for item_id 36 is 0.914730740181295
# Prediction for 24822 user_id for item_id 39 is 1.3442982654910858
# Prediction for 24822 user_id for item_id 40 is 0.9033099714176492
# Prediction for 24822 user_id for item_id 42 is 1.067231005540115
# Prediction for 24822 user_id for item_id 43 is 1.3672003078886434
# Prediction for 24822 user_id for item_id 50 is 0.9488186174371371
# Prediction for 24822 user_id for item_id 51 is 1.5900067379572844
# Prediction for 24822 user_id for item_id 54 is 0.5706560654328657
# Prediction for 24822 user_id for item_id 56 is 1.1640750711710441
# Prediction for 24822 user_id for item_id 57 is 0.9574464339975929
# Prediction for 24822 user_id for item_id 58 is 0.7780268600127168
# Prediction for 24822 user_id for item_id 59 is 0.27048955022005033
# Prediction for 24822 user_id for item_id 62 is 0.8643201164933383
# Prediction for 24822 user_id for item_id 63 is 1.4899059306811506
# Prediction for 24822 user_id for item_id 66 is 1.2380664477350272
# Prediction for 24822 user_id for item_id 69 is 1.2709745108982693
# Prediction for 24822 user_id for item_id 70 is 0.8249745442404611
# Prediction for 24822 user_id for item_id 71 is 1.158941820175096
# Prediction for 24822 user_id for item_id 72 is 0.38055268724810926
# Prediction for 24822 user_id for item_id 73 is 0.8026082611176087
# Prediction for 24822 user_id for item_id 75 is 0.6130067656851518
# Prediction for 24822 user_id for item_id 76 is 1.3645381785005433
# Prediction for 24822 user_id for item_id 77 is 0.9738734466422443
# Prediction for 24822 user_id for item_id 78 is 1.1430272950511338
# Prediction for 24822 user_id for item_id 79 is 1.4266188429754747
# Prediction for 24822 user_id for item_id 80 is 1.097356362421787
# Prediction for 24822 user_id for item_id 81 is 0.889323073961748
# Prediction for 24822 user_id for item_id 82 is 0.8556531445752833
# Prediction for 24822 user_id for item_id 83 is 1.0028446024715936
# Prediction for 24822 user_id for item_id 84 is 0.9530261995725999
# Prediction for 24822 user_id for item_id 85 is 0.9225130381591548
# Prediction for 24822 user_id for item_id 86 is 1.1324038086493917
# Prediction for 24822 user_id for item_id 87 is 0.5410606848146421
# Prediction for 24822 user_id for item_id 88 is 0.6353922236021246
# Prediction for 24822 user_id for item_id 89 is 0.8839920211518593
# Prediction for 24822 user_id for item_id 90 is 0.9473754264312798
# Prediction for 24822 user_id for item_id 91 is 1.0416703050094394
# Prediction for 24822 user_id for item_id 92 is 1.075279788342086
# Prediction for 24822 user_id for item_id 93 is 1.5395043773490986
# Prediction for 24822 user_id for item_id 94 is 1.2823610560796228
# Prediction for 24822 user_id for item_id 95 is 1.2333951323980283
# Prediction for 24822 user_id for item_id 96 is 0.6909451730884614
# Prediction for 24822 user_id for item_id 97 is 1.1944053228820322
# Prediction for 24822 user_id for item_id 98 is 1.2935809593910899
# Prediction for 24822 user_id for item_id 99 is 1.2400687180508767
# Prediction for 24823 user_id for item_id 57 is 0.3574981850555171
# Prediction for 24823 user_id for item_id 70 is 1.3204703877459165
# Prediction for 24823 user_id for item_id 71 is 1.2429171006009756
# Prediction for 24823 user_id for item_id 72 is 0.09933800107176938
# Prediction for 24823 user_id for item_id 73 is 0.6140351500563803
# Prediction for 24823 user_id for item_id 74 is 0.5524869480109624
# Prediction for 24823 user_id for item_id 75 is 0.9506964404070839
# Prediction for 24823 user_id for item_id 76 is 1.9611430560511933
# Prediction for 24823 user_id for item_id 77 is 1.525403753293568
# Prediction for 24823 user_id for item_id 78 is 0.9929366401110353
# Prediction for 24823 user_id for item_id 79 is 1.319050455772509
# Prediction for 24823 user_id for item_id 80 is 1.508676041166636
# Prediction for 24823 user_id for item_id 81 is 0.7603978381120313
# Prediction for 24823 user_id for item_id 82 is 0.9901001749369435
# Prediction for 24823 user_id for item_id 83 is 0.8693177166290925
# Prediction for 24823 user_id for item_id 84 is 1.1190878067467305
# Prediction for 24823 user_id for item_id 85 is 0.4615336038026495
# Prediction for 24823 user_id for item_id 86 is 1.1014924035983549
# Prediction for 24823 user_id for item_id 87 is 0.43743258035275323
# Prediction for 24823 user_id for item_id 88 is 0.9779048079695568
# Prediction for 24823 user_id for item_id 89 is 0.6676143900917653
# Prediction for 24823 user_id for item_id 90 is 1.1795478542280946
# Prediction for 24823 user_id for item_id 91 is 1.2011635911399858
# Prediction for 24823 user_id for item_id 92 is 1.2795930383380278
# Prediction for 24823 user_id for item_id 93 is 1.0765565911044301
# Prediction for 24823 user_id for item_id 94 is 1.054799021512028
# Prediction for 24823 user_id for item_id 95 is 0.8918853570233165
# Prediction for 24823 user_id for item_id 97 is 1.521235394442179
# Prediction for 24823 user_id for item_id 98 is 1.606270627867137
# Prediction for 24823 user_id for item_id 99 is 0.9436050592704245
# Prediction for 24825 user_id for item_id 0 is 1.3377690404282558
# Prediction for 24825 user_id for item_id 1 is 0.9636084161500933
# Prediction for 24825 user_id for item_id 2 is 0.7792677980522742
# Prediction for 24825 user_id for item_id 3 is 0.9018203648273789
# Prediction for 24825 user_id for item_id 8 is 1.6784762163701654
# Prediction for 24825 user_id for item_id 23 is 1.4408934977688195
# Prediction for 24825 user_id for item_id 36 is 0.878346239530446
# Prediction for 24825 user_id for item_id 42 is 1.3771116756399648
# Prediction for 24825 user_id for item_id 43 is 1.3200700408315496
# Prediction for 24825 user_id for item_id 56 is 1.191202129622361
# Prediction for 24825 user_id for item_id 57 is 0.6284882956674847
# Prediction for 24825 user_id for item_id 59 is 0.31045861650948914
# Prediction for 24825 user_id for item_id 70 is 1.2360354187483011
# Prediction for 24825 user_id for item_id 71 is 1.1276823943742127
# Prediction for 24825 user_id for item_id 72 is 0.22329373694993915
# Prediction for 24825 user_id for item_id 74 is 0.587284463880315
# Prediction for 24825 user_id for item_id 75 is 0.7525906469544966
# Prediction for 24825 user_id for item_id 77 is 1.3495083534009389
# Prediction for 24825 user_id for item_id 78 is 1.1751265913079971
# Prediction for 24825 user_id for item_id 79 is 1.3780430599624334
# Prediction for 24825 user_id for item_id 80 is 1.3558537043728358
# Prediction for 24825 user_id for item_id 81 is 0.7262678489686744
# Prediction for 24825 user_id for item_id 82 is 0.9346128836365886
# Prediction for 24825 user_id for item_id 83 is 1.0117974147704367
# Prediction for 24825 user_id for item_id 85 is 0.839826896783896
# Prediction for 24825 user_id for item_id 86 is 1.0682304684668624
# Prediction for 24825 user_id for item_id 87 is 0.4547876549981934
# Prediction for 24825 user_id for item_id 88 is 0.872852315446066
# Prediction for 24825 user_id for item_id 89 is 0.7569874472596836
# Prediction for 24825 user_id for item_id 90 is 1.063035992844604
# Prediction for 24825 user_id for item_id 91 is 1.3315016740273207
# Prediction for 24825 user_id for item_id 92 is 1.2517389719291145
# Prediction for 24825 user_id for item_id 93 is 1.3165571156198463
# Prediction for 24825 user_id for item_id 94 is 1.2824675665660186
# Prediction for 24825 user_id for item_id 95 is 1.1689908951276526
# Prediction for 24825 user_id for item_id 96 is 0.8442161319358638
# Prediction for 24825 user_id for item_id 97 is 1.4711402129108209
# Prediction for 24825 user_id for item_id 98 is 1.416018073278894
# Prediction for 24825 user_id for item_id 99 is 1.2642356254084337
# Prediction for 24826 user_id for item_id 0 is 0.9194158965526081
# Prediction for 24826 user_id for item_id 1 is 0.712017234744607
# Prediction for 24826 user_id for item_id 2 is 0.5383854993123229
# Prediction for 24826 user_id for item_id 3 is 0.7209193190167
# Prediction for 24826 user_id for item_id 5 is 0.4022092387918684
# Prediction for 24826 user_id for item_id 8 is 1.084673524284508
# Prediction for 24826 user_id for item_id 9 is 1.141693789084388
# Prediction for 24826 user_id for item_id 10 is 0.9464789751982015
# Prediction for 24826 user_id for item_id 11 is 0.6623757447899764
# Prediction for 24826 user_id for item_id 13 is 1.1066316612471945
# Prediction for 24826 user_id for item_id 21 is 1.2057256052748104
# Prediction for 24826 user_id for item_id 22 is 0.9911989602448156
# Prediction for 24826 user_id for item_id 23 is 0.7253444640255493
# Prediction for 24826 user_id for item_id 24 is 1.2669902760401779
# Prediction for 24826 user_id for item_id 25 is 1.1717266612497041
# Prediction for 24826 user_id for item_id 29 is 0.9810075403523839
# Prediction for 24826 user_id for item_id 32 is 0.5306150968517213
# Prediction for 24826 user_id for item_id 33 is 0.4174286506472554
# Prediction for 24826 user_id for item_id 36 is 0.7618818099169177
# Prediction for 24826 user_id for item_id 38 is 0.8057019840959199
# Prediction for 24826 user_id for item_id 39 is 0.9964177836867095
# Prediction for 24826 user_id for item_id 40 is 0.5467255462891701
# Prediction for 24826 user_id for item_id 42 is 0.8281185178173994
# Prediction for 24826 user_id for item_id 43 is 0.8366676457379107
# Prediction for 24826 user_id for item_id 44 is 0.4737732533087741
# Prediction for 24826 user_id for item_id 46 is 1.077981013547338
# Prediction for 24826 user_id for item_id 50 is 0.6119155657255466
# Prediction for 24826 user_id for item_id 51 is 1.09570086058326
# Prediction for 24826 user_id for item_id 54 is 0.4559475752056608
# Prediction for 24826 user_id for item_id 57 is 0.43064467855922367
# Prediction for 24826 user_id for item_id 58 is 0.7612245392995632
# Prediction for 24826 user_id for item_id 62 is 0.5847698318538611
# Prediction for 24826 user_id for item_id 63 is 0.9738522928771678
# Prediction for 24826 user_id for item_id 66 is 0.9235681594090901
# Prediction for 24826 user_id for item_id 69 is 0.7565850972275032
# Prediction for 24826 user_id for item_id 71 is 0.952823799587891
# Prediction for 24826 user_id for item_id 72 is 0.13148737239371655
# Prediction for 24826 user_id for item_id 73 is 0.44668387002140464
# Prediction for 24826 user_id for item_id 74 is 0.518037451913406
# Prediction for 24826 user_id for item_id 75 is 0.6055221546447592
# Prediction for 24826 user_id for item_id 76 is 1.2479414834508178
# Prediction for 24826 user_id for item_id 77 is 0.864917567629237
# Prediction for 24826 user_id for item_id 78 is 0.7195286563160447
# Prediction for 24826 user_id for item_id 79 is 0.9228544243970992
# Prediction for 24826 user_id for item_id 80 is 0.946631219341065
# Prediction for 24826 user_id for item_id 81 is 0.5267257785374729
# Prediction for 24826 user_id for item_id 82 is 0.6659900344830317
# Prediction for 24826 user_id for item_id 83 is 0.6104392709296163
# Prediction for 24826 user_id for item_id 85 is 0.41304428891713924
# Prediction for 24826 user_id for item_id 86 is 0.6746250439921255
# Prediction for 24826 user_id for item_id 87 is 0.39685820512062925
# Prediction for 24826 user_id for item_id 88 is 0.5220350726843901
# Prediction for 24826 user_id for item_id 89 is 0.46411509347854685
# Prediction for 24826 user_id for item_id 90 is 0.7014900258802675
# Prediction for 24826 user_id for item_id 91 is 0.6624779695634596
# Prediction for 24826 user_id for item_id 92 is 0.7562726512447061
# Prediction for 24826 user_id for item_id 93 is 0.9965468279224768
# Prediction for 24826 user_id for item_id 94 is 0.7733764388808664
# Prediction for 24826 user_id for item_id 95 is 0.6474779063672028
# Prediction for 24826 user_id for item_id 96 is 0.431435729396554
# Prediction for 24826 user_id for item_id 97 is 0.8399200400995596
# Prediction for 24826 user_id for item_id 98 is 1.0279375538203972
# Prediction for 24826 user_id for item_id 99 is 0.6835703779417649
# Prediction for 24827 user_id for item_id 0 is 0.7237913599436604
# Prediction for 24827 user_id for item_id 1 is 0.6944493315263451
# Prediction for 24827 user_id for item_id 2 is 0.6407860527578725
# Prediction for 24827 user_id for item_id 3 is 0.5948617774061621
# Prediction for 24827 user_id for item_id 8 is 0.7633134776159699
# Prediction for 24827 user_id for item_id 9 is 1.0999041154432252
# Prediction for 24827 user_id for item_id 23 is 0.6006640203605437
# Prediction for 24827 user_id for item_id 29 is 0.7407498706100156
# Prediction for 24827 user_id for item_id 32 is 0.49464991681610637
# Prediction for 24827 user_id for item_id 36 is 0.5889974467534566
# Prediction for 24827 user_id for item_id 42 is 0.6912349608776668
# Prediction for 24827 user_id for item_id 43 is 0.5120973956007869
# Prediction for 24827 user_id for item_id 50 is 0.6952301284147234
# Prediction for 24827 user_id for item_id 54 is 0.5442114790000251
# Prediction for 24827 user_id for item_id 56 is 0.8361787423379928
# Prediction for 24827 user_id for item_id 57 is 0.42088562180249345
# Prediction for 24827 user_id for item_id 63 is 0.6733308843144021
# Prediction for 24827 user_id for item_id 66 is 0.7204796110867031
# Prediction for 24827 user_id for item_id 69 is 0.6310866242439841
# Prediction for 24827 user_id for item_id 71 is 0.7524924140048598
# Prediction for 24827 user_id for item_id 72 is 0.18023407024992247
# Prediction for 24827 user_id for item_id 73 is 0.4325462339828307
# Prediction for 24827 user_id for item_id 74 is 0.3611392522580727
# Prediction for 24827 user_id for item_id 75 is 0.5179023629952731
# Prediction for 24827 user_id for item_id 76 is 1.017847426164061
# Prediction for 24827 user_id for item_id 77 is 0.7752341988103404
# Prediction for 24827 user_id for item_id 78 is 0.5871316508352832
# Prediction for 24827 user_id for item_id 79 is 0.9136938765934143
# Prediction for 24827 user_id for item_id 80 is 0.798961848550449
# Prediction for 24827 user_id for item_id 81 is 0.683616182822092
# Prediction for 24827 user_id for item_id 83 is 0.5559145279121173
# Prediction for 24827 user_id for item_id 84 is 0.592109691011188
# Prediction for 24827 user_id for item_id 85 is 0.3075847020002011
# Prediction for 24827 user_id for item_id 86 is 0.8891267156936726
# Prediction for 24827 user_id for item_id 87 is 0.2865326970847992
# Prediction for 24827 user_id for item_id 89 is 0.5830391439835512
# Prediction for 24827 user_id for item_id 90 is 0.7634375287364361
# Prediction for 24827 user_id for item_id 91 is 0.643340522863744
# Prediction for 24827 user_id for item_id 92 is 0.7777991978563862
# Prediction for 24827 user_id for item_id 93 is 0.7010311062763692
# Prediction for 24827 user_id for item_id 94 is 0.6535173896699308
# Prediction for 24827 user_id for item_id 95 is 0.6344941896086616
# Prediction for 24827 user_id for item_id 96 is 0.5340939443321274
# Prediction for 24827 user_id for item_id 97 is 0.9109115907778226
# Prediction for 24827 user_id for item_id 98 is 1.0018437373251032
# Prediction for 24827 user_id for item_id 99 is 0.5689328919306216
# Prediction for 24828 user_id for item_id 0 is 0.903902934040162
# Prediction for 24828 user_id for item_id 1 is 1.1355732985565914
# Prediction for 24828 user_id for item_id 2 is 0.9234207037258133
# Prediction for 24828 user_id for item_id 3 is 0.9973037428041605
# Prediction for 24828 user_id for item_id 5 is 0.8350427090233142
# Prediction for 24828 user_id for item_id 8 is 1.731454263525748
# Prediction for 24828 user_id for item_id 9 is 1.4483098417151579
# Prediction for 24828 user_id for item_id 10 is 1.305469099323309
# Prediction for 24828 user_id for item_id 11 is 0.8608814951576987
# Prediction for 24828 user_id for item_id 13 is 1.685565612213135
# Prediction for 24828 user_id for item_id 21 is 1.5966273617586808
# Prediction for 24828 user_id for item_id 22 is 1.2518749744750775
# Prediction for 24828 user_id for item_id 23 is 1.3397679036888086
# Prediction for 24828 user_id for item_id 24 is 1.5766410162880073
# Prediction for 24828 user_id for item_id 25 is 1.6883440109222287
# Prediction for 24828 user_id for item_id 29 is 1.720742867278329
# Prediction for 24828 user_id for item_id 32 is 0.6608739246322963
# Prediction for 24828 user_id for item_id 36 is 0.9878493505749543
# Prediction for 24828 user_id for item_id 38 is 1.093763901249487
# Prediction for 24828 user_id for item_id 39 is 1.5552923962001344
# Prediction for 24828 user_id for item_id 40 is 0.7277120381920993
# Prediction for 24828 user_id for item_id 44 is 1.0843808927792917
# Prediction for 24828 user_id for item_id 46 is 1.280936856913909
# Prediction for 24828 user_id for item_id 50 is 0.9055965307407152
# Prediction for 24828 user_id for item_id 51 is 1.7489802373387515
# Prediction for 24828 user_id for item_id 54 is 0.6435934240492569
# Prediction for 24828 user_id for item_id 57 is 1.0337565770872745
# Prediction for 24828 user_id for item_id 58 is 0.7722354130441439
# Prediction for 24828 user_id for item_id 59 is 0.20143786497016072
# Prediction for 24828 user_id for item_id 63 is 1.3412752213705326
# Prediction for 24828 user_id for item_id 66 is 1.212313447495644
# Prediction for 24828 user_id for item_id 69 is 1.372497725926152
# Prediction for 24828 user_id for item_id 70 is 0.687933464884191
# Prediction for 24828 user_id for item_id 71 is 1.2434374440556082
# Prediction for 24828 user_id for item_id 72 is 0.42480276099761277
# Prediction for 24828 user_id for item_id 73 is 0.7863583037187657
# Prediction for 24828 user_id for item_id 74 is 0.761014572245084
# Prediction for 24828 user_id for item_id 75 is 0.6458758220681962
# Prediction for 24828 user_id for item_id 77 is 0.8926517874604574
# Prediction for 24828 user_id for item_id 78 is 1.06825958419455
# Prediction for 24828 user_id for item_id 79 is 1.479711244748303
# Prediction for 24828 user_id for item_id 80 is 1.0600195467744231
# Prediction for 24828 user_id for item_id 81 is 1.0468455873993623
# Prediction for 24828 user_id for item_id 82 is 0.8630834565073713
# Prediction for 24828 user_id for item_id 83 is 0.9644522634898177
# Prediction for 24828 user_id for item_id 84 is 0.8931590738200178
# Prediction for 24828 user_id for item_id 85 is 0.8097943402663229
# Prediction for 24828 user_id for item_id 86 is 1.2588182421825318
# Prediction for 24828 user_id for item_id 88 is 0.5928580444720855
# Prediction for 24828 user_id for item_id 89 is 0.9602850288029574
# Prediction for 24828 user_id for item_id 90 is 0.9911927101995253
# Prediction for 24828 user_id for item_id 91 is 0.8754866982393482
# Prediction for 24828 user_id for item_id 92 is 1.0465870895067555
# Prediction for 24828 user_id for item_id 93 is 1.5562056084926605
# Prediction for 24828 user_id for item_id 94 is 1.2101319182110022
# Prediction for 24828 user_id for item_id 95 is 1.1851981477688784
# Prediction for 24828 user_id for item_id 96 is 0.6550142620269988
# Prediction for 24828 user_id for item_id 97 is 1.1383294556544148
# Prediction for 24828 user_id for item_id 98 is 1.36837636350062
# Prediction for 24828 user_id for item_id 99 is 1.111941356674679
# Prediction for 24830 user_id for item_id 8 is 0.9589931253716178
# Prediction for 24830 user_id for item_id 23 is 0.6180092216744979
# Prediction for 24830 user_id for item_id 36 is 0.8015597430219943
# Prediction for 24830 user_id for item_id 43 is 0.7222668114340268
# Prediction for 24830 user_id for item_id 56 is 0.9615076048868907
# Prediction for 24830 user_id for item_id 57 is 0.3500558496824747
# Prediction for 24830 user_id for item_id 66 is 0.9536105440165761
# Prediction for 24830 user_id for item_id 70 is 0.8192328580376308
# Prediction for 24830 user_id for item_id 71 is 1.0078939750911915
# Prediction for 24830 user_id for item_id 73 is 0.4422630371993044
# Prediction for 24830 user_id for item_id 74 is 0.4925506198080883
# Prediction for 24830 user_id for item_id 75 is 0.7085439794950057
# Prediction for 24830 user_id for item_id 76 is 1.4160284657920947
# Prediction for 24830 user_id for item_id 78 is 0.7084006337357253
# Prediction for 24830 user_id for item_id 79 is 0.9864481579466629
# Prediction for 24830 user_id for item_id 80 is 1.0716614827850621
# Prediction for 24830 user_id for item_id 81 is 0.6075541165147543
# Prediction for 24830 user_id for item_id 82 is 0.7305410008944424
# Prediction for 24830 user_id for item_id 83 is 0.618550924233203
# Prediction for 24830 user_id for item_id 84 is 0.7945457797166551
# Prediction for 24830 user_id for item_id 85 is 0.31373486493168323
# Prediction for 24830 user_id for item_id 86 is 0.802257684755948
# Prediction for 24830 user_id for item_id 87 is 0.38394968014832076
# Prediction for 24830 user_id for item_id 88 is 0.6394983087768376
# Prediction for 24830 user_id for item_id 89 is 0.5023505739773289
# Prediction for 24830 user_id for item_id 90 is 0.8346703201022138
# Prediction for 24830 user_id for item_id 91 is 0.7332111956026299
# Prediction for 24830 user_id for item_id 92 is 0.8699577486578954
# Prediction for 24830 user_id for item_id 93 is 0.9086155534221806
# Prediction for 24830 user_id for item_id 94 is 0.7548526976570017
# Prediction for 24830 user_id for item_id 95 is 0.6266138071004556
# Prediction for 24830 user_id for item_id 96 is 0.5261094658056071
# Prediction for 24830 user_id for item_id 97 is 0.9977637927457647
# Prediction for 24830 user_id for item_id 98 is 1.1854206793140025
# Prediction for 24830 user_id for item_id 99 is 0.638579670157018
# Prediction for 24831 user_id for item_id 70 is 0.5543783748160207
# Prediction for 24831 user_id for item_id 71 is 1.1142217308442277
# Prediction for 24831 user_id for item_id 72 is 0.13396701056961227
# Prediction for 24831 user_id for item_id 73 is 0.423501001292016
# Prediction for 24831 user_id for item_id 74 is 0.6345176705376898
# Prediction for 24831 user_id for item_id 75 is 0.6705593746543524
# Prediction for 24831 user_id for item_id 76 is 1.324080805213212
# Prediction for 24831 user_id for item_id 77 is 0.8251261222931515
# Prediction for 24831 user_id for item_id 78 is 0.7052893949997456
# Prediction for 24831 user_id for item_id 79 is 0.9435980696224614
# Prediction for 24831 user_id for item_id 80 is 0.9746958808321734
# Prediction for 24831 user_id for item_id 81 is 0.555414124497218
# Prediction for 24831 user_id for item_id 82 is 0.7023578189200718
# Prediction for 24831 user_id for item_id 83 is 0.5867014553542945
# Prediction for 24831 user_id for item_id 84 is 0.7540149814028603
# Prediction for 24831 user_id for item_id 85 is 0.35529313751371416
# Prediction for 24831 user_id for item_id 86 is 0.6389143494402696
# Prediction for 24831 user_id for item_id 87 is 0.4818696406356504
# Prediction for 24831 user_id for item_id 89 is 0.4441097754604338
# Prediction for 24831 user_id for item_id 90 is 0.6845396530769995
# Prediction for 24831 user_id for item_id 91 is 0.5078473806667656
# Prediction for 24831 user_id for item_id 92 is 0.6967655846429458
# Prediction for 24831 user_id for item_id 93 is 1.144596744700665
# Prediction for 24831 user_id for item_id 94 is 0.7512587101150336
# Prediction for 24831 user_id for item_id 95 is 0.5868335150349064
# Prediction for 24831 user_id for item_id 96 is 0.32804585523589713
# Prediction for 24831 user_id for item_id 97 is 0.7264616082415167
# Prediction for 24831 user_id for item_id 98 is 1.0800858910877484
# Prediction for 24831 user_id for item_id 99 is 0.6110883864647922
# Prediction for 24832 user_id for item_id 70 is 0.9097019815747692
# Prediction for 24832 user_id for item_id 71 is 0.3410637740005645
# Prediction for 24832 user_id for item_id 72 is 0.1216057684286539
# Prediction for 24832 user_id for item_id 73 is 0.47764219883410686
# Prediction for 24832 user_id for item_id 74 is 0.13155706080066346
# Prediction for 24832 user_id for item_id 75 is 0.29179901336765424
# Prediction for 24832 user_id for item_id 76 is 0.8116583519548304
# Prediction for 24832 user_id for item_id 77 is 0.8209133553398088
# Prediction for 24832 user_id for item_id 78 is 0.7100957873788595
# Prediction for 24832 user_id for item_id 79 is 0.7298339637178133
# Prediction for 24832 user_id for item_id 80 is 0.7071370432405782
# Prediction for 24832 user_id for item_id 81 is 0.3233709349617632
# Prediction for 24832 user_id for item_id 82 is 0.4569837588156147
# Prediction for 24832 user_id for item_id 83 is 0.6233876947420582
# Prediction for 24832 user_id for item_id 84 is 0.6121026232131611
# Prediction for 24832 user_id for item_id 85 is 0.6173871195519606
# Prediction for 24832 user_id for item_id 86 is 0.625387900459309
# Prediction for 24832 user_id for item_id 87 is 0.10928785357250875
# Prediction for 24832 user_id for item_id 88 is 0.5808474506237681
# Prediction for 24832 user_id for item_id 89 is 0.44662588312716395
# Prediction for 24832 user_id for item_id 90 is 0.6025410573343097
# Prediction for 24832 user_id for item_id 92 is 0.7994077544987576
# Prediction for 24832 user_id for item_id 93 is 0.5115451717258681
# Prediction for 24832 user_id for item_id 94 is 0.7860270359635059
# Prediction for 24832 user_id for item_id 95 is 0.7841288760272942
# Prediction for 24832 user_id for item_id 96 is 0.6472694005616744
# Prediction for 24832 user_id for item_id 97 is 1.0133487802407768
# Prediction for 24832 user_id for item_id 98 is 0.6751375208877715
# Prediction for 24832 user_id for item_id 99 is 0.8768363435702151
# Prediction for 24833 user_id for item_id 70 is 1.3464021674143565
# Prediction for 24833 user_id for item_id 71 is 0.720832062296011
# Prediction for 24833 user_id for item_id 72 is 0.25750968659942275
# Prediction for 24833 user_id for item_id 73 is 0.7430617298277616
# Prediction for 24833 user_id for item_id 74 is 0.2650282507525036
# Prediction for 24833 user_id for item_id 75 is 0.5991829967028077
# ...
# Prediction for 24976 user_id for item_id 75 is 0.6590910821116843
# Prediction for 24976 user_id for item_id 76 is 1.457203390268836
# Prediction for 24976 user_id for item_id 78 is 0.9910521528525618
# Prediction for 24976 user_id for item_id 79 is 1.260996744242269
# Prediction for 24976 user_id for item_id 80 is 1.1790895881159036
# Prediction for 24976 user_id for item_id 81 is 0.7651080169871438
# Prediction for 24976 user_id for item_id 82 is 0.8166706517679887
# Prediction for 24976 user_id for item_id 83 is 0.8904687360824132
# Prediction for 24976 user_id for item_id 84 is 0.9384769787101729
# Prediction for 24976 user_id for item_id 85 is 0.6806727084533694
# Prediction for 24976 user_id for item_id 86 is 1.1190135532077174
# Prediction for 24976 user_id for item_id 87 is 0.34824336250100635
# Prediction for 24976 user_id for item_id 88 is 0.8282226498283374
# Prediction for 24976 user_id for item_id 89 is 0.7621349886354124
# Prediction for 24976 user_id for item_id 90 is 1.0312776238051737
# Prediction for 24976 user_id for item_id 91 is 1.2161521932822896
# Prediction for 24976 user_id for item_id 92 is 1.1758649238090397
# Prediction for 24977 user_id for item_id 0 is 0.515233731614381
# Prediction for 24977 user_id for item_id 1 is 0.6204214162301541
# Prediction for 24977 user_id for item_id 2 is 0.49745464910708487
# Prediction for 24977 user_id for item_id 3 is 0.5540902981613396
# Prediction for 24977 user_id for item_id 5 is 0.4448097812971946
# Prediction for 24977 user_id for item_id 8 is 0.9569333295774348
# Prediction for 24977 user_id for item_id 9 is 0.8031258963160799
# Prediction for 24977 user_id for item_id 11 is 0.47220339885041807
# Prediction for 24977 user_id for item_id 13 is 0.9278915200941635
# Prediction for 24977 user_id for item_id 21 is 0.88659134515797
# Prediction for 24977 user_id for item_id 22 is 0.7001828996970002
# Prediction for 24977 user_id for item_id 23 is 0.7281767231563226
# Prediction for 24977 user_id for item_id 24 is 0.8845693077174799
# Prediction for 24977 user_id for item_id 25 is 0.9251185142656262
# Prediction for 24977 user_id for item_id 27 is 0.4506386429455354
# Prediction for 24977 user_id for item_id 29 is 0.9462691333154134
# Prediction for 24977 user_id for item_id 32 is 0.36404398483671313
# Prediction for 24977 user_id for item_id 33 is 0.4234001464775151
# Prediction for 24977 user_id for item_id 36 is 0.5534663342569945
# Prediction for 24977 user_id for item_id 37 is 0.4919140358898613
# Prediction for 24977 user_id for item_id 38 is 0.6013387269307692
# Prediction for 24977 user_id for item_id 39 is 0.8465018493480659
# Prediction for 24977 user_id for item_id 40 is 0.40486459334610325
# Prediction for 24977 user_id for item_id 42 is 0.524152061427193
# Prediction for 24977 user_id for item_id 44 is 0.5772221465469298
# Prediction for 24977 user_id for item_id 46 is 0.7132918777132595
# Prediction for 24977 user_id for item_id 50 is 0.49006424059683507
# Prediction for 24977 user_id for item_id 51 is 0.9608038089087634
# Prediction for 24977 user_id for item_id 54 is 0.34933109513369437
# Prediction for 24977 user_id for item_id 56 is 0.6779779869356815
# Prediction for 24977 user_id for item_id 57 is 0.5553324004072905
# Prediction for 24977 user_id for item_id 58 is 0.4407030615919773
# Prediction for 24977 user_id for item_id 59 is 0.1112198686052326
# Prediction for 24977 user_id for item_id 62 is 0.36018479873705056
# Prediction for 24977 user_id for item_id 63 is 0.7483583614591078
# Prediction for 24977 user_id for item_id 66 is 0.6765087368239847
# Prediction for 24977 user_id for item_id 69 is 0.7506316255325237
# Prediction for 24977 user_id for item_id 71 is 0.6954332703307141
# Prediction for 24977 user_id for item_id 72 is 0.22388247546207288
# Prediction for 24977 user_id for item_id 74 is 0.42456616191350915
# Prediction for 24977 user_id for item_id 75 is 0.36487838415330576
# Prediction for 24977 user_id for item_id 76 is 0.7552047324583558
# Prediction for 24977 user_id for item_id 77 is 0.5019468436041188
# Prediction for 24977 user_id for item_id 78 is 0.589055014311566
# Prediction for 24977 user_id for item_id 79 is 0.8066362089475663
# Prediction for 24977 user_id for item_id 80 is 0.595642920799276
# Prediction for 24977 user_id for item_id 81 is 0.5591427627146243
# Prediction for 24977 user_id for item_id 83 is 0.5274019412813719
# Prediction for 24977 user_id for item_id 84 is 0.5003289851798003
# Prediction for 24977 user_id for item_id 85 is 0.4403671083209265
# Prediction for 24977 user_id for item_id 86 is 0.6718338774926664
# Prediction for 24977 user_id for item_id 87 is 0.32367415634751534
# Prediction for 24977 user_id for item_id 88 is 0.3277445749792344
# Prediction for 24977 user_id for item_id 89 is 0.5122914307202513
# Prediction for 24977 user_id for item_id 90 is 0.5405763914580474
# Prediction for 24977 user_id for item_id 91 is 0.47975427907034257
# Prediction for 24977 user_id for item_id 92 is 0.5724531943334124
# Prediction for 24977 user_id for item_id 93 is 0.8629844515810117
# Prediction for 24977 user_id for item_id 94 is 0.6642377515117284
# Prediction for 24977 user_id for item_id 95 is 0.641117762677373
# Prediction for 24977 user_id for item_id 96 is 0.35182038649521236
# Prediction for 24977 user_id for item_id 97 is 0.6206181201276214
# Prediction for 24977 user_id for item_id 98 is 0.7545316721066448
# Prediction for 24977 user_id for item_id 99 is 0.60847313184184
# Prediction for 24979 user_id for item_id 70 is 1.3208841215791998
# Prediction for 24979 user_id for item_id 71 is 1.3965928832989838
# Prediction for 24979 user_id for item_id 72 is 0.17538922556608202
# Prediction for 24979 user_id for item_id 73 is 0.7321750544322825
# Prediction for 24979 user_id for item_id 74 is 0.6931256364812547
# Prediction for 24979 user_id for item_id 76 is 2.051325167067615
# Prediction for 24979 user_id for item_id 77 is 1.547858374342985
# Prediction for 24979 user_id for item_id 78 is 1.1689851725097489
# Prediction for 24979 user_id for item_id 79 is 1.4843430100819661
# Prediction for 24980 user_id for item_id 0 is 0.5359058625291594
# Prediction for 24980 user_id for item_id 1 is 0.6239025578222169
# Prediction for 24980 user_id for item_id 2 is 0.546536196106223
# Prediction for 24980 user_id for item_id 3 is 0.47125725169953586
# Prediction for 24980 user_id for item_id 5 is 0.554025154769183
# Prediction for 24980 user_id for item_id 8 is 1.2130773630014893
# Prediction for 24980 user_id for item_id 9 is 0.5503650267471135
# Prediction for 24980 user_id for item_id 10 is 0.8634257810426803
# Prediction for 24980 user_id for item_id 11 is 0.4340589717059538
# Prediction for 24980 user_id for item_id 21 is 0.9809389983231092
# Prediction for 24980 user_id for item_id 22 is 0.7563082358360139
# Prediction for 24980 user_id for item_id 23 is 1.2380309510362728
# Prediction for 24980 user_id for item_id 24 is 1.001898966750096
# Prediction for 24980 user_id for item_id 29 is 0.8884361054595873
# Prediction for 24980 user_id for item_id 32 is 0.6988840369269237
# Prediction for 24980 user_id for item_id 33 is 0.48616589671583094
# Prediction for 24980 user_id for item_id 36 is 0.38481415531448265
# Prediction for 24980 user_id for item_id 38 is 0.6743285397339821
# Prediction for 24980 user_id for item_id 39 is 0.7377767714772709
# Prediction for 24980 user_id for item_id 42 is 0.7312341871404638
# Prediction for 24980 user_id for item_id 43 is 0.9001701134192421
# Prediction for 24980 user_id for item_id 44 is 0.7204692074011941
# Prediction for 24980 user_id for item_id 51 is 0.8454794396271792
# Prediction for 24980 user_id for item_id 54 is 0.34949014408752205
# Prediction for 24980 user_id for item_id 56 is 0.6856847243788864
# Prediction for 24980 user_id for item_id 57 is 0.6651550754061184
# Prediction for 24980 user_id for item_id 58 is 0.3287464522057692
# Prediction for 24980 user_id for item_id 59 is 0.24398217280967033
# Prediction for 24980 user_id for item_id 62 is 0.6217905311688324
# Prediction for 24980 user_id for item_id 63 is 0.9886364316463933
# Prediction for 24980 user_id for item_id 66 is 0.7085774896747351
# Prediction for 24980 user_id for item_id 69 is 0.7333893076023174
# Prediction for 24980 user_id for item_id 70 is 0.6388985174128673
# Prediction for 24980 user_id for item_id 72 is 0.3013103544461875
# Prediction for 24980 user_id for item_id 73 is 0.5980948732521996
# Prediction for 24980 user_id for item_id 74 is 0.3213332520680964
# Prediction for 24980 user_id for item_id 75 is 0.2535633677575761
# Prediction for 24980 user_id for item_id 76 is 0.683519582981217
# Prediction for 24980 user_id for item_id 77 is 0.6070958923477173
# Prediction for 24980 user_id for item_id 78 is 0.7952142551991195
# Prediction for 24980 user_id for item_id 79 is 0.9397214861059375
# Prediction for 24980 user_id for item_id 80 is 0.6112870650671852
# Prediction for 24980 user_id for item_id 81 is 0.589038436226126
# Prediction for 24980 user_id for item_id 82 is 0.4896401728396945
# Prediction for 24980 user_id for item_id 83 is 0.7196740074753687
# Prediction for 24980 user_id for item_id 84 is 0.5771094193679196
# Prediction for 24980 user_id for item_id 85 is 0.7631051309284294
# Prediction for 24980 user_id for item_id 86 is 0.8315283213670095
# Prediction for 24980 user_id for item_id 87 is 0.24773694250831335
# Prediction for 24980 user_id for item_id 88 is 0.45002226204451895
# Prediction for 24980 user_id for item_id 89 is 0.6650314640698886
# Prediction for 24980 user_id for item_id 90 is 0.6239320004044971
# Prediction for 24980 user_id for item_id 91 is 0.8855762394972531
# Prediction for 24980 user_id for item_id 92 is 0.7701615105080644
# Prediction for 24980 user_id for item_id 93 is 0.8667520304839288
# Prediction for 24980 user_id for item_id 94 is 0.9132506771995976
# Prediction for 24980 user_id for item_id 95 is 0.9637624766882195
# Prediction for 24980 user_id for item_id 96 is 0.5927220495362927
# Prediction for 24980 user_id for item_id 97 is 0.9103713502801083
# Prediction for 24980 user_id for item_id 98 is 0.7359142351599988
# Prediction for 24980 user_id for item_id 99 is 0.967951876451181
# Prediction for 24981 user_id for item_id 0 is 0.8823030499875277
# Prediction for 24981 user_id for item_id 1 is 0.7943392131947331
# Prediction for 24981 user_id for item_id 2 is 0.6619965875585023
# Prediction for 24981 user_id for item_id 3 is 0.7335126515276429
# Prediction for 24981 user_id for item_id 5 is 0.5358002740847883
# Prediction for 24981 user_id for item_id 8 is 1.0932375799794873
# Prediction for 24981 user_id for item_id 9 is 1.2092007996153311
# Prediction for 24981 user_id for item_id 10 is 0.9507160105084457
# Prediction for 24981 user_id for item_id 11 is 0.7463271266907376
# Prediction for 24981 user_id for item_id 13 is 1.1671493315558124
# Prediction for 24981 user_id for item_id 21 is 1.241094210477697
# Prediction for 24981 user_id for item_id 22 is 0.9835325572440375
# Prediction for 24981 user_id for item_id 23 is 0.8106205475383509
# Prediction for 24981 user_id for item_id 24 is 1.2345104968010574
# Prediction for 24981 user_id for item_id 29 is 1.0145177284217837
# Prediction for 24981 user_id for item_id 32 is 0.5769044280219979
# Prediction for 24981 user_id for item_id 33 is 0.46883337488373766
# Prediction for 24981 user_id for item_id 36 is 0.7454380299516224
# Prediction for 24981 user_id for item_id 37 is 0.8126893456397614
# Prediction for 24981 user_id for item_id 39 is 1.1514328349071707
# Prediction for 24981 user_id for item_id 40 is 0.5469266244251674
# Prediction for 24981 user_id for item_id 42 is 0.8365752381590764
# Prediction for 24981 user_id for item_id 43 is 0.7974261950315163
# Prediction for 24981 user_id for item_id 44 is 0.6357880529364235
# Prediction for 24981 user_id for item_id 46 is 1.1170693063920327
# Prediction for 24981 user_id for item_id 50 is 0.7317658695649246
# Prediction for 24981 user_id for item_id 51 is 1.1727171563036474
# Prediction for 24981 user_id for item_id 56 is 0.9418112683993574
# Prediction for 24981 user_id for item_id 57 is 0.5283111898716596
# Prediction for 24981 user_id for item_id 58 is 0.7199872078588951
# Prediction for 24981 user_id for item_id 59 is 0.1363110785877817
# Prediction for 24981 user_id for item_id 62 is 0.49349550918102164
# Prediction for 24981 user_id for item_id 63 is 0.9510548083368648
# Prediction for 24981 user_id for item_id 66 is 0.9206817579556006
# Prediction for 24981 user_id for item_id 69 is 0.8157620300237384
# Prediction for 24981 user_id for item_id 70 is 0.7171497274132843
# Prediction for 24981 user_id for item_id 71 is 0.9417342747945222
# Prediction for 24981 user_id for item_id 72 is 0.19963265416528383
# Prediction for 24981 user_id for item_id 73 is 0.5147442567024209
# Prediction for 24981 user_id for item_id 75 is 0.5988462832313072
# Prediction for 24981 user_id for item_id 76 is 1.2210949601693637
# Prediction for 24981 user_id for item_id 77 is 0.8812897600926138
# Prediction for 24981 user_id for item_id 78 is 0.7531151166301393
# Prediction for 24981 user_id for item_id 80 is 0.947477047255018
# Prediction for 24981 user_id for item_id 81 is 0.6890679866683469
# Prediction for 24981 user_id for item_id 82 is 0.6889992947603686
# Prediction for 24981 user_id for item_id 83 is 0.6723983829783057
# Prediction for 24981 user_id for item_id 84 is 0.7382429528149896
# Prediction for 24981 user_id for item_id 85 is 0.4537287032561
# Prediction for 24981 user_id for item_id 86 is 0.8850161462127636
# Prediction for 24981 user_id for item_id 87 is 0.38795598694495365
# Prediction for 24981 user_id for item_id 88 is 0.5712714125645573
# Prediction for 24981 user_id for item_id 89 is 0.6098164304495634
# Prediction for 24981 user_id for item_id 90 is 0.8064131947908887
# Prediction for 24981 user_id for item_id 91 is 0.7370918165847016
# Prediction for 24981 user_id for item_id 92 is 0.8523870361751636
# Prediction for 24981 user_id for item_id 93 is 0.9879933409062178
# Prediction for 24981 user_id for item_id 94 is 0.8283017158224345
# Prediction for 24981 user_id for item_id 95 is 0.7588029561058506
# Prediction for 24981 user_id for item_id 96 is 0.5399068379435419
# Prediction for 24981 user_id for item_id 97 is 0.9682507423450073
# Prediction for 24981 user_id for item_id 98 is 1.1125285532236884
# Prediction for 24981 user_id for item_id 99 is 0.7406848206804215
# Prediction for 24982 user_id for item_id 71 is 0.7738419376612782
# Prediction for 24982 user_id for item_id 72 is 0.2131329136974632
# Prediction for 24982 user_id for item_id 73 is 0.5901428429956012
# Prediction for 24982 user_id for item_id 74 is 0.38886151710373207
# Prediction for 24982 user_id for item_id 75 is 0.5224236036995953
# Prediction for 24982 user_id for item_id 76 is 1.1702037284515432
# Prediction for 24982 user_id for item_id 77 is 0.966259875639627
# Prediction for 24982 user_id for item_id 78 is 0.8491496985781137
# Prediction for 24982 user_id for item_id 79 is 1.0684859264639344
# Prediction for 24982 user_id for item_id 80 is 0.9526575332840096
# Prediction for 24982 user_id for item_id 81 is 0.6504934691656464
# Prediction for 24982 user_id for item_id 82 is 0.6742039948189025
# Prediction for 24982 user_id for item_id 83 is 0.7611333652499714
# Prediction for 24982 user_id for item_id 84 is 0.7747630952936839
# Prediction for 24982 user_id for item_id 85 is 0.618251628654238
# Prediction for 24982 user_id for item_id 87 is 0.30552905028158767
# Prediction for 24982 user_id for item_id 88 is 0.6604885993017494
# Prediction for 24982 user_id for item_id 89 is 0.6572084973096602
# Prediction for 24982 user_id for item_id 90 is 0.8405845878004161
# Prediction for 24982 user_id for item_id 91 is 1.0039532436234406
# Prediction for 24982 user_id for item_id 92 is 0.9653383836575298
# Prediction for 24982 user_id for item_id 93 is 0.900606740795926
# Prediction for 24982 user_id for item_id 94 is 0.9424361035214187
# Prediction for 24982 user_id for item_id 95 is 0.9134588683271447
# Prediction for 24982 user_id for item_id 96 is 0.6923662215005012
# Prediction for 24982 user_id for item_id 97 is 1.150927662777235
# Prediction for 24982 user_id for item_id 98 is 1.067854570598162
# Prediction for 24982 user_id for item_id 99 is 0.9322183125650652

# %%
test_idx
# Out:
# (array([    0,     0,     0, ..., 24982, 24982, 24982]),
#  array([70, 71, 72, ..., 97, 98, 99]))

# %%
num_iter = 100
hist = sgd(num_iter)  # Note how the MSE decreases with the number of iterations
plt.figure()
plt.plot(np.arange(0, num_iter, 5), hist)
plt.xlabel("Iterations")
plt.ylabel("MSE")
plt.show()
# Out:
# Iteration 0/100:	MSE=25.652842
# Iteration 5/100:	MSE=24.486616
# Iteration 10/100:	MSE=23.813462
# Iteration 15/100:	MSE=22.945091
# Iteration 20/100:	MSE=21.167428
# Iteration 25/100:	MSE=18.722917
# Iteration 30/100:	MSE=17.763463
# Iteration 35/100:	MSE=17.474668
# Iteration 40/100:	MSE=17.333030
# Iteration 45/100:	MSE=17.231617
# Iteration 50/100:	MSE=17.137678
# Iteration 55/100:	MSE=17.033929
# Iteration 60/100:	MSE=16.909005
# Iteration 65/100:	MSE=16.757455
# Iteration 70/100:	MSE=16.581676
# Iteration 75/100:	MSE=16.393011
# Iteration 80/100:	MSE=16.209252
# Iteration 85/100:	MSE=16.046533
# Iteration 90/100:	MSE=15.911904
# Iteration 95/100:	MSE=15.803768

# %%
jester_nan.iloc[55,13]
# Out:
# 6.07

# %%
df_items = pd.read_excel('https://github.com/albanda/CE888/blob/master/lab4-recommender/movies_latent_factors.xlsx?raw=true')
df_users = pd.read_excel('https://github.com/albanda/CE888/blob/master/lab4-recommender/movies_latent_factors.xlsx?raw=true', sheet_name=1)

# %%
df_users.set_index('User', inplace=True)

# %%
df_items.set_index('Movie ID', inplace=True)

# %%
df_items[df_items['Factor8'] == df_items['Factor8'].max()]
# Out:
#                              Title   Factor1  ...  Factor14  Factor15
# Movie ID                                      ...
# 24        Kill Bill: Vol. 1 (2003) -0.645019  ... -0.385681  1.036656
#
# [1 rows x 16 columns]

# %%
items_latent = df_items.drop('Title', axis=1).values

# %%
user_latent = df_users.values

# %%
user_latent.shape
# Out:
# (25, 15)

# %%
items_latent.shape
# Out:
# (100, 15)

# %%
def predict_movie_rating(user, movie):
  user_arr = df_users.loc[user].values
  movie_arr = df_items.loc[movie].drop('Title').values
  return user_arr.dot(movie_arr)

# %%
def top_n_recommendation(user, n):
  pred = {}
  for movie in df_items.index:
    pred[movie] = predict_movie_rating(user, movie)
  pred = dict(sorted(pred.items(), key=lambda kv: kv[1], reverse=True))
  movies = list(pred.keys())
  return movies[:n]

# %%
predict_movie_rating(2067, 120)
# Out:
# -1.9595769003233463

# %%
predict_movie_rating(156, 9331)
# Out:
# -0.041432658849076896

# %%
top_n_recommendation(4940, 3)
# Out:
# [13, 278, 603]

# %%
df_items.loc[top_n_recommendation(768, 2)]['Title']
# Out:
# Movie ID
# 597         Titanic (1997)
# 114    Pretty Woman (1990)
# Name: Title, dtype: object
